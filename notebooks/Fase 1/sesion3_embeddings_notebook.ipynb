# %% [markdown]
# # Sesión 2: De Palabras a Embeddings
#
# **Curso:** Introducción a Large Language Models
# **Profesor:** Francisco Pérez Carbajal
# **Basado en:** Hands-On Large Language Models, Chapter 1
#
# ---
#
# ## 📚 Contenido
#
# 1. **Bag-of-Words**: El enfoque clásico
# 2. **Word2Vec**: Embeddings que capturan significado
# 3. **Explorando similitudes**
# 4. **Analogías y operaciones**
# 5. **Visualización en 2D**
#
# ---
#
# ## Objetivos
#
# - ✅ Entender las limitaciones de bag-of-words
# - ✅ Aprender qué son los embeddings
# - ✅ Usar word2vec pre-entrenado
# - ✅ Calcular similitudes semánticas
# - ✅ Visualizar embeddings

# %% [markdown]
# ---
#
# # Parte 1: Bag-of-Words
#
# ## El Problema
#
# Las computadoras solo entienden números. ¿Cómo representamos texto?
#
# **Solución clásica:** Contar palabras → "Bag of Words"

# %%
# Instalar dependencias
# !pip install scikit-learn gensim matplotlib -q

# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
import numpy as np

# Corpus de ejemplo
textos = [
    "El gato come pescado",
    "El perro come carne",
    "El gato y el perro son amigos"
]

print("📝 Documentos originales:")
for i, texto in enumerate(textos, 1):
    print(f"  {i}. {texto}")

# %% [markdown]
# ### Crear Representación Bag-of-Words

# %%
# Crear vectorizador
vectorizer = CountVectorizer()

# Transformar textos a vectores
X = vectorizer.fit_transform(textos)

# Obtener vocabulario
vocab = vectorizer.get_feature_names_out()

print(f"\n📖 Vocabulario ({len(vocab)} palabras):")
print(vocab)

print("\n🔢 Vectores (Bag-of-Words):")
print(X.toarray())

# %% [markdown]
# ### Visualización en Tabla

# %%
# Crear DataFrame para visualización
df = pd.DataFrame(
    X.toarray(),
    columns=vocab,
    index=[f"Doc {i}" for i in range(1, len(textos)+1)]
)

print("\n📊 Tabla de Bag-of-Words:")
display(df)

# %% [markdown]
# ### 🎯 Tu Turno: Agrega tu Oración
#
# Modifica la lista `textos` arriba y vuelve a ejecutar las celdas.

# %% [markdown]
# ---
#
# ## ❌ Limitaciones de Bag-of-Words
#
# ### Problema 1: Ignora el Orden

# %%
# Dos oraciones con diferente significado
oraciones = [
    "El gato persigue al ratón",
    "El ratón persigue al gato"  # Significado diferente!
]

vec = CountVectorizer()
X = vec.fit_transform(oraciones)

print("Oración 1:", oraciones[0])
print("Oración 2:", oraciones[1])
print("\n¿Misma representación?")
print(np.array_equal(X[0].toarray(), X[1].toarray()))  # True!

print("\nVectores:")
print(X.toarray())
print("\n❌ ¡Bag-of-words no puede distinguirlos!")

# %% [markdown]
# ### Problema 2: No Captura Significado

# %%
# Palabras con significado similar
oraciones_sinonimos = [
    "Vi un gato",
    "Vi un felino"  # Mismo significado
]

vec = CountVectorizer()
X = vec.fit_transform(oraciones_sinonimos)

print("Vocabulario:", vec.get_feature_names_out())
print("\nVectores:")
print(X.toarray())
print("\n❌ 'gato' y 'felino' son completamente diferentes!")
print("   (aunque significan lo mismo)")

# %% [markdown]
# ### Problema 3: Alta Dimensionalidad

# %%
# Simular un vocabulario grande
textos_largos = [
    "El gato come pescado fresco del mar",
    "Los perros juegan en el parque grande",
    "Los pájaros cantan en los árboles altos",
    "El sol brilla sobre las montañas nevadas"
]

vec = CountVectorizer()
X = vec.fit_transform(textos_largos)

print(f"Vocabulario: {len(vec.get_feature_names_out())} palabras")
print(f"Tamaño de vector por documento: {X.shape[1]} dimensiones")
print(f"\nSparsity (porcentaje de ceros): {100 * (1 - X.nnz / (X.shape[0] * X.shape[1])):.1f}%")
print("\n❌ La mayoría son ceros → ineficiente")

# %% [markdown]
# ---
#
# # Parte 2: Word2Vec - Embeddings
#
# ## 💡 La Solución
#
# En lugar de **contar**, **aprendemos** representaciones densas que capturan significado.
#
# **Word2Vec (2013):** "Conocerás una palabra por las compañías que tiene"

# %% [markdown]
# ## Cargar Modelo Pre-entrenado

# %%
import gensim.downloader as api

# Cargar modelo (puede tardar ~1 minuto la primera vez)
print("Descargando word2vec...")
print("(Esto toma ~1 min la primera vez)\n")

model = api.load('word2vec-google-news-300')

print("✓ Modelo cargado")
print(f"✓ Vocabulario: {len(model):,} palabras")
print(f"✓ Dimensión de embeddings: {model.vector_size}")

# %% [markdown]
# ## Explorar un Embedding

# %%
# Obtener embedding de "cat"
palabra = "cat"
embedding = model[palabra]

print(f"Embedding de '{palabra}':")
print(f"  Dimensiones: {len(embedding)}")
print(f"  Primeros 10 valores: {embedding[:10]}")
print(f"  Tipo: vector denso (todos valores diferentes)")

# %% [markdown]
# ---
#
# # Parte 3: Similitud Semántica
#
# ## Palabras Más Similares

# %%
# Encontrar palabras similares a "cat"
palabra = "cat"
similares = model.most_similar(palabra, topn=10)

print(f"🔍 Palabras más similares a '{palabra}':")
print("\nPalabra         Similitud")
print("-" * 30)
for palabra_sim, score in similares:
    print(f"{palabra_sim:15s} {score:.4f}")

# %% [markdown]
# ### 🎯 Tu Turno: Explora Palabras

# %%
# Prueba con diferentes palabras
palabras_explorar = ["king", "computer", "happy", "soccer"]

for palabra in palabras_explorar:
    print(f"\n{'='*40}")
    print(f"Similares a '{palabra}':")
    print(f"{'='*40}")
    similares = model.most_similar(palabra, topn=5)
    for pal, score in similares:
        print(f"  {pal:15s} {score:.4f}")

# %%
# Agrega tu propia palabra aquí
mi_palabra = ""  # Cambia esto

if mi_palabra:
    try:
        similares = model.most_similar(mi_palabra, topn=5)
        print(f"Similares a '{mi_palabra}':")
        for pal, score in similares:
            print(f"  {pal}: {score:.4f}")
    except KeyError:
        print(f"❌ '{mi_palabra}' no está en el vocabulario")
        print("   Prueba con otra palabra en inglés")

# %% [markdown]
# ## Similitud Entre Pares

# %%
# Comparar similitudes
pares = [
    ("cat", "feline"),    # Sinónimos
    ("cat", "dog"),       # Animales relacionados
    ("cat", "car"),       # No relacionados
    ("king", "queen"),    # Relacionados
    ("man", "woman"),     # Relacionados
]

print("📊 Similitud entre pares:\n")
print(f"{'Par':<25} Similitud")
print("-" * 40)

for palabra1, palabra2 in pares:
    similitud = model.similarity(palabra1, palabra2)
    par_str = f"{palabra1} ↔ {palabra2}"
    print(f"{par_str:<25} {similitud:.4f}")

# %% [markdown]
# ---
#
# # Parte 4: Analogías
#
# ## Operaciones Famosas
#
# **Idea:** Rey - Hombre + Mujer ≈ Reina

# %%
# Analogía clásica: King - Man + Woman = Queen
resultado = model.most_similar(
    positive=['woman', 'king'],
    negative=['man'],
    topn=5
)

print("👑 King - Man + Woman = ?\n")
for palabra, score in resultado:
    print(f"  {palabra:15s} {score:.4f}")

print("\n✓ ¡El resultado es 'queen'!")

# %%
# Más ejemplos de analogías
analogias = [
    {
        'nombre': 'Países y Capitales',
        'ecuacion': 'Paris - France + Germany = ?',
        'positive': ['Paris', 'Germany'],
        'negative': ['France']
    },
    {
        'nombre': 'Masculino/Femenino',
        'ecuacion': 'actor - man + woman = ?',
        'positive': ['actor', 'woman'],
        'negative': ['man']
    },
    {
        'nombre': 'Verbos',
        'ecuacion': 'walking - walk + swim = ?',
        'positive': ['walking', 'swim'],
        'negative': ['walk']
    }
]

for analogia in analogias:
    print(f"\n{'='*50}")
    print(f"🧪 {analogia['nombre']}")
    print(f"{'='*50}")
    print(f"Ecuación: {analogia['ecuacion']}\n")
    
    resultado = model.most_similar(
        positive=analogia['positive'],
        negative=analogia['negative'],
        topn=3
    )
    
    for palabra, score in resultado:
        print(f"  {palabra:15s} {score:.4f}")

# %% [markdown]
# ### 🎯 Tu Turno: Crea tu Analogía

# %%
# Diseña tu propia analogía
# Formato: A - B + C = ?

mi_analogia = model.most_similar(
    positive=['', ''],  # A y C
    negative=[''],      # B
    topn=5
)

# Descomenta y completa:
# print("Mi analogía:")
# for palabra, score in mi_analogia:
#     print(f"  {palabra}: {score:.4f}")

# %% [markdown]
# ---
#
# # Parte 5: Visualización en 2D
#
# ## Reducir Dimensiones
#
# Embeddings tienen 300 dimensiones. Vamos a reducirlos a 2D para visualizar.

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# Seleccionar palabras para visualizar
palabras_animales = ['cat', 'dog', 'lion', 'tiger', 'elephant', 'mouse']
palabras_vehiculos = ['car', 'bus', 'truck', 'bicycle', 'motorcycle', 'train']
palabras = palabras_animales + palabras_vehiculos

# Obtener embeddings
embeddings = np.array([model[palabra] for palabra in palabras])

print(f"Embeddings originales: {embeddings.shape}")
print("Reduciendo a 2D con t-SNE...")

# Reducir dimensiones (300 → 2)
tsne = TSNE(n_components=2, random_state=42, perplexity=5)
embeddings_2d = tsne.fit_transform(embeddings)

print(f"Embeddings reducidos: {embeddings_2d.shape}")
print("✓ Listo para visualizar")

# %%
# Crear visualización
plt.figure(figsize=(12, 8))

# Separar por categoría
x_animales = embeddings_2d[:len(palabras_animales), 0]
y_animales = embeddings_2d[:len(palabras_animales), 1]

x_vehiculos = embeddings_2d[len(palabras_animales):, 0]
y_vehiculos = embeddings_2d[len(palabras_animales):, 1]

# Graficar
plt.scatter(x_animales, y_animales, c='red', s=100, alpha=0.6, label='Animales')
plt.scatter(x_vehiculos, y_vehiculos, c='blue', s=100, alpha=0.6, label='Vehículos')

# Añadir etiquetas
for i, palabra in enumerate(palabras):
    plt.annotate(
        palabra,
        xy=(embeddings_2d[i, 0], embeddings_2d[i, 1]),
        xytext=(5, 5),
        textcoords='offset points',
        fontsize=12,
        fontweight='bold'
    )

plt.title('Visualización de Embeddings en 2D', fontsize=16, fontweight='bold')
plt.xlabel('Dimensión 1', fontsize=12)
plt.ylabel('Dimensión 2', fontsize=12)
plt.legend(fontsize=12)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print("\n📊 Observa cómo:")
print("   • Animales están agrupados (cluster rojo)")
print("   • Vehículos están agrupados (cluster azul)")
print("   • Palabras similares están cerca en el espacio")

# %% [markdown]
# ### 🎯 Tu Turno: Visualiza tus Palabras

# %%
# Elige tus propias palabras para visualizar
mis_palabras = [
    'king', 'queen', 'prince', 'princess',  # Realeza
    'apple', 'banana', 'orange', 'grape'    # Frutas
]

# Obtener embeddings
mis_embeddings = np.array([model[w] for w in mis_palabras])

# Reducir a 2D
tsne = TSNE(n_components=2, random_state=42, perplexity=3)
mis_embeddings_2d = tsne.fit_transform(mis_embeddings)

# Graficar
plt.figure(figsize=(10, 8))
plt.scatter(mis_embeddings_2d[:, 0], mis_embeddings_2d[:, 1], s=150, alpha=0.6)

for i, palabra in enumerate(mis_palabras):
    plt.annotate(
        palabra,
        xy=(mis_embeddings_2d[i, 0], mis_embeddings_2d[i, 1]),
        fontsize=12
    )

plt.title('Mis Palabras en 2D')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ---
#
# # Resumen y Reflexión
#
# ## ✅ Lo que Aprendimos
#
# ### 1. Bag-of-Words
# - ✓ Representa texto contando palabras
# - ✗ Ignora orden
# - ✗ No captura significado
# - ✗ Alta dimensionalidad (sparse)
#
# ### 2. Embeddings (Word2Vec)
# - ✓ Vectores densos (300D)
# - ✓ Capturan significado semántico
# - ✓ Palabras similares → vectores cercanos
# - ✓ Permiten operaciones (analogías)
#
# ### 3. Aplicaciones
# - Similitud semántica
# - Búsqueda de sinónimos
# - Clustering de palabras
# - Base para LLMs modernos
#
# ---
#
# ## 💡 Insights Clave
#
# 1. **Representación importa:** Cómo representamos el lenguaje afecta todo lo demás
#
# 2. **Significado en contexto:** Word2Vec aprende significado viendo vecinos
#
# 3. **Geometría semántica:** Similitud = distancia en espacio vectorial
#
# 4. **Fundamento de LLMs:** Todos los modelos modernos usan embeddings
#
# ---
#
# ## 🔮 Próxima Sesión
#
# **Sesión 3:** Tipos de Embeddings
#
# - Sentence embeddings (frases completas)
# - Document embeddings (documentos)
# - Modelos contextuales (BERT)
# - Aplicaciones prácticas
#
# ---
#
# ## 🏠 Para Explorar (Opcional)
#
# 1. Prueba más palabras y analogías
# 2. Visualiza diferentes categorías semánticas
# 3. Piensa: ¿Qué aplicación podrías hacer con similitud semántica?
#
# ---
#
# ## 📚 Referencias
#
# - **Libro:** Hands-On Large Language Models (Chapter 1)
# - **Paper:** Mikolov et al. (2013) - "Efficient Estimation of Word Representations"
# - **Biblioteca:** Gensim - https://radimrehurek.com/gensim/
# - **Visualización:** Jay Alammar's blog - https://jalammar.github.io/
# - **Word2Vec tutorial:** https://tensorflow.org
#
# **¿Dudas?** franciscop@ciencias.unam.mx
